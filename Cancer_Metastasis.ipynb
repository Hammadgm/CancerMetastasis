# %%
import GEOparse

# %%
#getting data after downloading GSE14020 soft file
gse = GEOparse.get_GEO(geo="GSE14020", destdir = "./")
# Out:
# 09-Jul-2020 22:39:31 DEBUG utils - Directory ./ already exists. Skipping.
# 09-Jul-2020 22:39:31 INFO GEOparse - File already exist: using local version.
# 09-Jul-2020 22:39:31 INFO GEOparse - Parsing ./GSE14020_family.soft.gz:
# 09-Jul-2020 22:39:31 DEBUG GEOparse - DATABASE: GeoMiame
# 09-Jul-2020 22:39:31 DEBUG GEOparse - SERIES: GSE14020
# 09-Jul-2020 22:39:31 DEBUG GEOparse - PLATFORM: GPL96
# 09-Jul-2020 22:39:33 DEBUG GEOparse - PLATFORM: GPL570
# C:\Users\Hammad\Anaconda3\lib\site-packages\GEOparse\GEOparse.py:104: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   return parse_GSE(filepath)
# 09-Jul-2020 22:39:38 DEBUG GEOparse - SAMPLE: GSM352095
# 09-Jul-2020 22:39:38 DEBUG GEOparse - SAMPLE: GSM352097
# 09-Jul-2020 22:39:38 DEBUG GEOparse - SAMPLE: GSM352098
# 09-Jul-2020 22:39:39 DEBUG GEOparse - SAMPLE: GSM352100
# 09-Jul-2020 22:39:39 DEBUG GEOparse - SAMPLE: GSM352101
# ...

# %%
gse.gpls['GPL96'].columns
# Out:
#                                                                         description
# ID                                Affymetrix Probe Set ID LINK_PRE:"https://www....
# GB_ACC                            GenBank Accession Number LINK_PRE:"http://www....
# SPOT_ID                                                         identifies controls
# Species Scientific Name           The genus and species of the organism represen...
# Annotation Date                   The date that the annotations for this probe a...
# Sequence Type
# Sequence Source                   The database from which the sequence used to d...
# Target Description
# Representative Public ID          The accession number of a representative seque...
# Gene Title                              Title of Gene represented by the probe set.
# Gene Symbol                       A gene symbol, when one is available (from Uni...
# ENTREZ_GENE_ID                    Entrez Gene Database UID LINK_PRE:"http://www....
# ...

# %%
gse.gsms["GSM352095"].table
# Out:
#                      ID_REF      VALUE
# 0                 1007_s_at  11.942972
# 1                   1053_at   9.124514
# 2                    117_at   7.832843
# 3                    121_at   9.293999
# 4                 1255_g_at   4.545640
# ...                     ...        ...
# 54670  AFFX-r2-Ec-bioC-5_at   9.612546
# 54671  AFFX-r2-Ec-bioD-3_at  12.215268
# 54672  AFFX-r2-Ec-bioD-5_at  11.681449
# 54673   AFFX-r2-P1-cre-3_at  13.761771
# 54674   AFFX-r2-P1-cre-5_at  13.626195
#
# [54675 rows x 2 columns]

# %%
#gse = GEOparse.get_GEO(geo="GSE14020", destdir="./")
print()
print("GSM example:")
for gsm_name, gsm in gse.gsms.items():
    print("Name: ", gsm_name)
    print("Metadata:",)
    for key, value in gsm.metadata.items():
        print(" - %s : %s" % (key, ", ".join(value)))
        print ("Table data:",)
        print (gsm.table.head())
        break
print()
print("GPL example:")
for gpl_name, gpl in gse.gpls.items():
    print("Name: ", gpl_name)
    print("Metadata:",)
    for key, value in gpl.metadata.items():
        print(" - %s : %s" % (key, ", ".join(value)))
    print("Table data:",)
    print(gpl.table.head())
    break
# Out:
# GSM example:
# Name:  GSM352095
# Metadata:
#  - title : 5381T (U133plus2): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.942972
# 1    1053_at   9.124514
# 2     117_at   7.832843
# 3     121_at   9.293999
# 4  1255_g_at   4.545640
# Name:  GSM352097
# Metadata:
#  - title : 102962T (U133plus2): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  12.028198
# 1    1053_at   9.478611
# 2     117_at   8.056224
# 3     121_at   9.734242
# 4  1255_g_at   4.589639
# Name:  GSM352098
# Metadata:
#  - title : 104406T (U133plus2): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  12.359949
# 1    1053_at   8.936268
# 2     117_at   8.230384
# 3     121_at   9.196800
# 4  1255_g_at   4.443698
# Name:  GSM352100
# Metadata:
#  - title : 105079T (U133plus2): Bone metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.589025
# 1    1053_at   8.035468
# 2     117_at  10.979582
# 3     121_at   9.359527
# ...

# %%
controls = ['GSM352095',
'GSM352097',
'GSM352098',
'GSM352100',
'GSM352101',
'GSM352103',
'GSM352105',
'GSM352107',
'GSM352109',
'GSM352110',
'GSM352111',
'GSM352113',
'GSM352114',
'GSM352115',
'GSM352117',
'GSM352119',
'GSM352120',
'GSM352121',
'GSM352122',
'GSM352123',
'GSM352124',
'GSM352125',
'GSM352126',
'GSM352127',
'GSM352128',
'GSM352129',
'GSM352130',
'GSM352131',
'GSM352132',
'GSM352133',
'GSM352134',
'GSM352135',
'GSM352136',
'GSM352137',
'GSM352138',
'GSM352139',
'GSM352140',
'GSM352141',
'GSM352142',
'GSM352143',
'GSM352144',
'GSM352145',
'GSM352146',
'GSM352147',
'GSM352148',
'GSM352149',
'GSM352150',
'GSM352151',
'GSM352152',
'GSM352153',
'GSM352154',
'GSM352155',
'GSM352156',
'GSM352157',
'GSM352158',
'GSM352159',
'GSM352160',
'GSM352161',
'GSM352162',
'GSM352163',
'GSM352164',
'GSM352165',
'GSM352166',
'GSM352167',
'GSM352168']

# %%
pivoted_control_samples = gse.pivot_samples('VALUE')[controls]
pivoted_control_samples.head(5)
# Out:
# name       GSM352095  GSM352097  GSM352098  GSM352100  GSM352101  GSM352103  \
# ID_REF
# 1007_s_at  11.942972  12.028198  12.359949  11.589025  11.405878  10.658286
# 1053_at     9.124514   9.478611   8.936268   8.035468   9.168375   8.102512
# 117_at      7.832843   8.056224   8.230384  10.979582   7.907716   8.983309
# 121_at      9.293999   9.734242   9.196800   9.359527   9.449023   9.438934
# 1255_g_at   4.545640   4.589639   4.443698   4.633253   4.698722   4.755724
#
# name       GSM352105  GSM352107  GSM352109  GSM352110  ...  GSM352159  \
# ID_REF                                                 ...
# 1007_s_at  10.835002  12.091930  12.085872  12.344569  ...  11.220281
# 1053_at     9.247241   9.189113   8.306166   9.104509  ...   6.946830
# 117_at      9.381022   7.796607   8.537037   7.934914  ...   8.465121
# 121_at      9.383646   9.080720   9.423481   9.555070  ...   9.332640
# 1255_g_at   4.530701   4.644450   4.574697   4.610129  ...   5.060824
#
# ...

# %%
import pandas as pd
df= pd.DataFrame(pivoted_control_samples)

# %%
df.isnull().sum()
# Out:
# name
# GSM352095        6
# GSM352097        6
# GSM352098        6
# GSM352100        6
# GSM352101        6
#              ...
# GSM352164    32398
# GSM352165    32398
# GSM352166    32398
# GSM352167    32398
# GSM352168    32398
# Length: 65, dtype: int64

# %%
cols=['GSM352095']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352097']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352098']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352100']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352101']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352103']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352105']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352107']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352109']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352110']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352111']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352113']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352115']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352117']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352119']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352120']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352121']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352122']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352123']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352124']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352125']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352126']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352127']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352128']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352129']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352130']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352131']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352132']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352133']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352134']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352135']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352136']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352137']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352138']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352139']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352140']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352141']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352142']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352143']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352144']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352145']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352146']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352147']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352148']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352149']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352150']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352151']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352152']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352153']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352154']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352155']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352156']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352157']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352158']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352159']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352160']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352161']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352162']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352163']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352164']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352165']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352166']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352167']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352168']
df[cols]=df[cols].fillna(df.mean().iloc[0])

# %%
df.isnull().sum()
# Out:
# name
# GSM352095    0
# GSM352097    0
# GSM352098    0
# GSM352100    0
# GSM352101    0
#             ..
# GSM352164    0
# GSM352165    0
# GSM352166    0
# GSM352167    0
# GSM352168    0
# Length: 65, dtype: int64

# %%
import GEOparse
import pandas as pd
import pylab as pl
import seaborn as sns

# %%
pl.rcParams['figure.figsize'] = (14, 10)
pl.rcParams['ytick.labelsize'] = 12
pl.rcParams['xtick.labelsize'] = 11
pl.rcParams['axes.labelsize'] = 23
pl.rcParams['legend.fontsize'] = 20
sns.set_style('ticks')
c1, c2, c3, c4 = sns.color_palette("Set1", 4)
df.hist()
sns.despine(offset=10, trim=True)

# %%
df = pd.read_csv("MLProject.csv",index_col = 0)

# %%
df
# Out:
#                         GSM352095  GSM352097  GSM352098  GSM352100  GSM352101  \
# ID_REF
# 1007_s_at               11.942972  12.028198  12.359949  11.589025  11.405878
# 1053_at                  9.124514   9.478611   8.936268   8.035468   9.168375
# 117_at                   7.832843   8.056224   8.230384  10.979582   7.907716
# 121_at                   9.293999   9.734242   9.196800   9.359527   9.449023
# 1255_g_at                4.545640   4.589639   4.443698   4.633253   4.698722
# ...                           ...        ...        ...        ...        ...
# AFFX-r2-Hs28SrRNA-3_at   7.167422   7.167422   7.167422   7.167422   7.167422
# AFFX-r2-Hs28SrRNA-5_at   7.167422   7.167422   7.167422   7.167422   7.167422
# AFFX-r2-Hs28SrRNA-M_at   7.167422   7.167422   7.167422   7.167422   7.167422
# AFFX-r2-P1-cre-3_at     13.761771  14.173357  14.213187  13.966082  14.098767
# AFFX-r2-P1-cre-5_at     13.626195  13.999518  14.064820  13.751962  13.838414
#
# ...

# %%
df=df.T.reset_index()
df
# Out:
# ID_REF      index  1007_s_at   1053_at     117_at    121_at  1255_g_at  \
# 0       GSM352095  11.942972  9.124514   7.832843  9.293999   4.545640
# 1       GSM352097  12.028198  9.478611   8.056224  9.734242   4.589639
# 2       GSM352098  12.359949  8.936268   8.230384  9.196800   4.443698
# 3       GSM352100  11.589025  8.035468  10.979582  9.359527   4.633253
# 4       GSM352101  11.405878  9.168375   7.907716  9.449023   4.698722
# ..            ...        ...       ...        ...       ...        ...
# 61      GSM352164  10.253499  6.999848   7.746652  8.943775   4.862778
# 62      GSM352165  11.060955  7.609674   7.653508  9.081481   4.880778
# 63      GSM352166  10.999642  6.644695   7.794672  9.145070   4.906529
# 64      GSM352167   9.523839  6.741417   8.241767  9.340316   4.975271
# 65      GSM352168  10.644172  6.826809   8.210786  9.089787   5.329008
#
# ID_REF   1294_at   1316_at   1320_at  1405_i_at  ...  AFFX-r2-Ec-bioD-3_at  \
# ...

# %%
df.head(5)
# Out:
# ID_REF      index  1007_s_at   1053_at     117_at    121_at  1255_g_at  \
# 0       GSM352095  11.942972  9.124514   7.832843  9.293999   4.545640
# 1       GSM352097  12.028198  9.478611   8.056224  9.734242   4.589639
# 2       GSM352098  12.359949  8.936268   8.230384  9.196800   4.443698
# 3       GSM352100  11.589025  8.035468  10.979582  9.359527   4.633253
# 4       GSM352101  11.405878  9.168375   7.907716  9.449023   4.698722
#
# ID_REF   1294_at   1316_at   1320_at  1405_i_at  ...  AFFX-r2-Ec-bioD-3_at  \
# 0       7.871945  6.762140  5.872532   7.875702  ...             12.215268
# 1       8.008909  6.868611  5.940234   7.202162  ...             12.794652
# 2       8.337189  6.834461  5.671500   8.024927  ...             12.884326
# 3       8.527015  7.062760  6.015733   7.383561  ...             12.362589
# 4       7.976891  7.905617  5.884391   5.839641  ...             12.569956
#
# ID_REF  AFFX-r2-Ec-bioD-5_at  AFFX-r2-Hs18SrRNA-3_s_at  \
# ...

# %%
#Genotype-phenotype studies are done for predicting traits i.e. a particular disease given their only genome
gse.phenotype_data.head(5)
# Out:
#                                            title geo_accession  \
# GSM352095     5381T (U133plus2): Lung metastasis     GSM352095
# GSM352097  102962T (U133plus2): Brain metastasis     GSM352097
# GSM352098  104406T (U133plus2): Brain metastasis     GSM352098
# GSM352100   105079T (U133plus2): Bone metastasis     GSM352100
# GSM352101  107502T (U133plus2): Brain metastasis     GSM352101
#
#                           status submission_date last_update_date type  \
# GSM352095  Public on May 01 2009     Dec 17 2008      Aug 28 2018  RNA
# GSM352097  Public on May 01 2009     Dec 17 2008      Aug 28 2018  RNA
# GSM352098  Public on May 01 2009     Dec 17 2008      Aug 28 2018  RNA
# GSM352100  Public on May 01 2009     Dec 17 2008      Aug 28 2018  RNA
# GSM352101  Public on May 01 2009     Dec 17 2008      Aug 28 2018  RNA
#
#           channel_count source_name_ch1  organism_ch1 taxid_ch1  ...  \
# GSM352095             1            Lung  Homo sapiens      9606  ...
# ...

# %%
samples = gse.phenotype_data[['geo_accession','source_name_ch1']]
samples
# Out:
#           geo_accession source_name_ch1
# GSM352095     GSM352095            Lung
# GSM352097     GSM352097           Brain
# GSM352098     GSM352098           Brain
# GSM352100     GSM352100            Bone
# GSM352101     GSM352101           Brain
# ...                 ...             ...
# GSM352164     GSM352164            Lung
# GSM352165     GSM352165            Lung
# GSM352166     GSM352166            Lung
# GSM352167     GSM352167            Bone
# GSM352168     GSM352168            Lung
#
# [65 rows x 2 columns]

# %%
#add metastatsis colum corresponding to relevant GSMs
df['Metastasis'] = samples['source_name_ch1']

for i in range(len(df)): 
    if df['index'][i] == 'GSM352095': 
        df['Metastasis'][i]="Lung"
  
    elif df['index'][i] == 'GSM352097': 
        df['Metastasis'][i]="Brain"
  
    elif df['index'][i] == 'GSM352098': 
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352100':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352101':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352103':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352105':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352107':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352109':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352110':
        df['Metastasis'][i]="Brain"
    
    elif df['index'][i] == 'GSM352111':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352113':
        df['Metastasis'][i]="Brain"
    
    elif df['index'][i] == 'GSM352114':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352115':
        df['Metastasis'][i]="Brain"
    
    elif df['index'][i] == 'GSM352117':
        df['Metastasis'][i]="Bone"    
        
    elif df['index'][i] == 'GSM352119':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352120':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352121':
        df['Metastasis'][i]="Brain"  
        
    elif df['index'][i] == 'GSM352122':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352123':
        df['Metastasis'][i]="Bone"   
        
    elif df['index'][i] == 'GSM352124':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352125':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352126':
        df['Metastasis'][i]="Bone"
     
    elif df['index'][i] == 'GSM352127':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352128':
        df['Metastasis'][i]="Brain"  
        
    elif df['index'][i] == 'GSM352129':
        df['Metastasis'][i]="Brain"    
        
    elif df['index'][i] == 'GSM352130':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352131':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352132':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352133':
        df['Metastasis'][i]="Lung"    
        
    elif df['index'][i] == 'GSM352134':
        df['Metastasis'][i]="Lung"   
            
    elif df['index'][i] == 'GSM352135':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352136':
        df['Metastasis'][i]="Liver"
        
    elif df['index'][i] == 'GSM352137':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352138':
        df['Metastasis'][i]="Lung"    
        
    elif df['index'][i] == 'GSM352139':
        df['Metastasis'][i]="Liver"    
        
    elif df['index'][i] == 'GSM352140':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352141':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352142':
        df['Metastasis'][i]="Brain"    
        
    elif df['index'][i] == 'GSM352143':
        df['Metastasis'][i]="Lung"  
        
    elif df['index'][i] == 'GSM352144':
        df['Metastasis'][i]="Bone"    
        
    elif df['index'][i] == 'GSM352145':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352146':
        df['Metastasis'][i]="Liver"
        
    elif df['index'][i] == 'GSM352147':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352148':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352149':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352150':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352151':
        df['Metastasis'][i]="Bone"    
        
    elif df['index'][i] == 'GSM352152':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352153':
        df['Metastasis'][i]="Brain"   
        
    elif df['index'][i] == 'GSM352154':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352155':
        df['Metastasis'][i]="Bone"    
        
    elif df['index'][i] == 'GSM352156':
        df['Metastasis'][i]="Lung"    
        
    elif df['index'][i] == 'GSM352157':
        df['Metastasis'][i]="Liver"   
        
    elif df['index'][i] == 'GSM352158':
        df['Metastasis'][i]="Lung"
        
        
    elif df['index'][i] == 'GSM352159':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352160':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352161':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352162':
        df['Metastasis'][i]="Liver"
        
    elif df['index'][i] == 'GSM352163':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352164':
        df['Metastasis'][i]="Lung"     
        
    elif df['index'][i] == 'GSM352165':
        df['Metastasis'][i]="Lung"   
        
    elif df['index'][i] == 'GSM352166':
        df['Metastasis'][i]="Lung"   
        
    elif df['index'][i] == 'GSM352167':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352168':
        df['Metastasis'][i]="Lung"
# Out:
# C:\Users\Hammad\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Hammad\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Hammad\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# ...

# %%
df.head(5)
# Out:
# ID_REF      index  1007_s_at   1053_at     117_at    121_at  1255_g_at  \
# 0       GSM352095  11.942972  9.124514   7.832843  9.293999   4.545640
# 1       GSM352097  12.028198  9.478611   8.056224  9.734242   4.589639
# 2       GSM352098  12.359949  8.936268   8.230384  9.196800   4.443698
# 3       GSM352100  11.589025  8.035468  10.979582  9.359527   4.633253
# 4       GSM352101  11.405878  9.168375   7.907716  9.449023   4.698722
#
# ID_REF   1294_at   1316_at   1320_at  1405_i_at  ...  AFFX-r2-Ec-bioD-5_at  \
# 0       7.871945  6.762140  5.872532   7.875702  ...             11.681449
# 1       8.008909  6.868611  5.940234   7.202162  ...             12.391372
# 2       8.337189  6.834461  5.671500   8.024927  ...             12.547635
# 3       8.527015  7.062760  6.015733   7.383561  ...             11.959521
# 4       7.976891  7.905617  5.884391   5.839641  ...             12.259550
#
# ID_REF  AFFX-r2-Hs18SrRNA-3_s_at  AFFX-r2-Hs18SrRNA-5_at  \
# ...

# %%
df.isnull().sum()
# Out:
# ID_REF
# index                     0
# 1007_s_at                 0
# 1053_at                   0
# 117_at                    0
# 121_at                    0
#                          ..
# AFFX-r2-Hs28SrRNA-5_at    0
# AFFX-r2-Hs28SrRNA-M_at    0
# AFFX-r2-P1-cre-3_at       0
# AFFX-r2-P1-cre-5_at       0
# Metastasis                1
# Length: 54683, dtype: int64

# %%
#cols=['AFFX-r2-Hs28SrRNA-5_at']
#df[cols]=df[cols].fillna(df.mean().iloc[0])

#cols=['Metastasis']
#df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['Metastasis']
df[cols]=df[cols].fillna(df.mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# ID_REF
# index                     0
# 1007_s_at                 0
# 1053_at                   0
# 117_at                    0
# 121_at                    0
#                          ..
# AFFX-r2-Hs28SrRNA-5_at    0
# AFFX-r2-Hs28SrRNA-M_at    0
# AFFX-r2-P1-cre-3_at       0
# AFFX-r2-P1-cre-5_at       0
# Metastasis                0
# Length: 54683, dtype: int64

# %%
data = df.drop(columns=['index'])
df1 = data.dropna()
df1
# Out:
# ID_REF  1007_s_at   1053_at     117_at    121_at  1255_g_at   1294_at  \
# 0       11.942972  9.124514   7.832843  9.293999   4.545640  7.871945
# 1       12.028198  9.478611   8.056224  9.734242   4.589639  8.008909
# 2       12.359949  8.936268   8.230384  9.196800   4.443698  8.337189
# 3       11.589025  8.035468  10.979582  9.359527   4.633253  8.527015
# 4       11.405878  9.168375   7.907716  9.449023   4.698722  7.976891
# ..            ...       ...        ...       ...        ...       ...
# 61      10.253499  6.999848   7.746652  8.943775   4.862778  8.790295
# 62      11.060955  7.609674   7.653508  9.081481   4.880778  7.839485
# 63      10.999642  6.644695   7.794672  9.145070   4.906529  8.669564
# 64       9.523839  6.741417   8.241767  9.340316   4.975271  8.623906
# 65      10.644172  6.826809   8.210786  9.089787   5.329008  9.198012
#
# ID_REF   1316_at   1320_at  1405_i_at   1431_at  ...  AFFX-r2-Ec-bioD-5_at  \
# ...

# %%
#defining x and y and removing metastasis from data frame as i'm going to predict metastasis 
import numpy as np
x=df1
y=df1['Metastasis']
del x['Metastasis']

# %%
#Applying feature Scalling in order to normalize the data and speed up the calculations in an algorithm.
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x1 = sc.fit_transform(x)

# %%
categorical_feature_columns = list(set(df.columns) - set(df._get_numeric_data().columns))
categorical_feature_columns
# Out:
# ['index', 'Metastasis']

# %%
numerical_feature_columns = list(df._get_numeric_data().columns)
numerical_feature_columns
# Out:
# ['1007_s_at',
#  '1053_at',
#  '117_at',
#  '121_at',
#  '1255_g_at',
#  '1294_at',
#  '1316_at',
#  '1320_at',
#  '1405_i_at',
#  '1431_at',
#  '1438_at',
#  '1487_at',
#  '1494_f_at',
#  '1552256_a_at',
#  '1552257_a_at',
#  '1552258_at',
#  '1552261_at',
#  '1552263_at',
#  '1552264_a_at',
#  '1552266_at',
#  '1552269_at',
#  '1552271_at',
#  '1552272_a_at',
#  '1552274_at',
#  '1552275_s_at',
#  '1552276_a_at',
#  '1552277_a_at',
#  '1552278_a_at',
#  '1552279_a_at',
#  '1552280_at',
#  '1552281_at',
#  '1552283_s_at',
#  '1552286_at',
#  '1552287_s_at',
#  '1552288_at',
#  '1552289_a_at',
#  '1552291_at',
#  '1552293_at',
#  '1552295_a_at',
#  '1552296_at',
#  '1552299_at',
#  '1552301_a_at',
#  '1552302_at',
#  '1552303_a_at',
#  '1552304_at',
#  '1552306_at',
#  '1552307_a_at',
#  '1552309_a_at',
#  '1552310_at',
#  '1552311_a_at',
#  '1552312_a_at',
#  '1552314_a_at',
#  '1552315_at',
#  '1552316_a_at',
#  '1552318_at',
#  '1552319_a_at',
#  '1552320_a_at',
# ...

# %%
x.shape
# Out:
# (66, 54681)

# %%
y.shape
# Out:
# (66,)

# %%
#Feature Selection
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# %%
select_feature = SelectKBest(chi2, k=20).fit(x,y)

# %%
selected_features_df = pd.DataFrame({'Feature' : list(x.columns),
                                    'Scores' : select_feature.scores_})
selected_features_df.sort_values(by = 'Scores', ascending = False)
# Out:
#            Feature     Scores
# 54258     37004_at  34.803691
# 15355  205908_s_at  33.334935
# 28119    218835_at  32.242999
# 26713  217428_s_at  28.894758
# 15160  205713_s_at  28.611773
# ...            ...        ...
# 42122    232869_at   0.000093
# 49263    240014_at   0.000092
# 26661    217376_at   0.000088
# 47384    238135_at   0.000074
# 26528    217242_at   0.000056
#
# [54681 rows x 2 columns]

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt

model = ExtraTreesClassifier()
model.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
print (model.feature_importances_)
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
feat_importances = pd.Series(model.feature_importances_, index = x.columns)
plt.figure(figsize = (12,8))
feat_importances.nlargest(20).plot(kind = 'barh')
plt.show()

# %%
feature_list = list(feat_importances.nlargest(20).to_frame().index)
feature_list
# Out:
# ['203540_at',
#  '38691_s_at',
#  '214836_x_at',
#  '212354_at',
#  '203939_at',
#  '209542_x_at',
#  '227249_at',
#  '214043_at',
#  '205982_x_at',
#  '205941_s_at',
#  '202095_s_at',
#  '235494_at',
#  '203542_s_at',
#  '37004_at',
#  '216893_s_at',
#  '207134_x_at',
#  '209147_s_at',
#  '207542_s_at',
#  '203186_s_at',
#  '41856_at']

# %%
x = x[feature_list]
x
# Out:
# ID_REF  203540_at  38691_s_at  214836_x_at  212354_at  203939_at  209542_x_at  \
# 0        6.119438   10.854450    12.292617   9.495888   7.158804     7.443931
# 1        7.273372    8.818800    10.818660   8.526068   7.345562     7.083052
# 2        7.897030    8.515224    11.722311   9.148646   6.061072     7.155548
# 3        6.248813    8.780358     9.891379  12.791881   9.902202     8.150258
# 4        9.618781    8.548785     9.369573   8.550875   4.990738     6.986115
# ..            ...         ...          ...        ...        ...          ...
# 61       5.490178   12.482789    10.108047   8.424297   6.409407     7.876965
# 62       5.560908   10.142010    11.993540   8.381723   6.394808     7.210451
# 63       5.569142   14.655848    11.079390   7.998008   6.217649     7.136598
# 64       5.635442    8.721330     8.664212  10.679851   8.789436     7.642374
# 65       5.777179   13.873733    11.334597   8.426522   5.942639     7.964597
#
# ...

# %%
#As the data is now scalled and label encoding is done now lets split out data into train and test
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3 , random_state=0)

# %%
# Fitting XGBClassifier to the training data: Model_1 
from xgboost import XGBClassifier

# %%
classifier_1 = XGBClassifier()
classifier_1.fit(xtrain,ytrain)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='multi:softprob', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# Fitting SVM to the training data: Model 2
from sklearn.svm import SVC

# %%
#applying the model2 on training dataset
classifier_2 = svc_model  = SVC()

# %%
classifier_2.fit(xtrain, ytrain)
# Out:
# SVC()

# %%
## Fitting Random Forest Classifier to the training data: Model 3
from sklearn.ensemble import RandomForestClassifier

# %%
classifier_3=RandomForestClassifier(n_estimators = 20)
classifier_3.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
#Import knearest neighbors Classifier model4
from sklearn.neighbors import KNeighborsClassifier

#Create KNN Classifier
knn = KNeighborsClassifier(n_neighbors=19)

#Train the model using the training sets
knn.fit(xtrain, ytrain)

#Predict the response for test dataset
#ypred_4 = knn.predict(xtest)
#ypred_4
# Out:
# KNeighborsClassifier(n_neighbors=19)

# %%
#Import Gaussian Naive Bayes model
from sklearn.naive_bayes import GaussianNB

#Create a Gaussian Classifier
gnb = GaussianNB()

#Train the model using the training sets
gnb.fit(xtrain, ytrain)

#Predict the response for test dataset
#ypred_6 = gnb.predict(xtest)
#ypred_6
# Out:
# GaussianNB()

# %%
from sklearn.model_selection import cross_val_score

from sklearn.model_selection import KFold, cross_val_score
#from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
Kfold = KFold(len(x),shuffle = False)
print("KfoldCrossVal score using XGBoster is %s" %cross_val_score(classifier_1,x,y,cv=10).mean())
# Out:
# C:\Users\Hammad\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 5 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# KfoldCrossVal score using XGBoster is 0.8214285714285714

# %%
Kfold = KFold(len(x),shuffle = False)
print("KfoldCrossVal score using SVM is %s" %cross_val_score(classifier_2,x,y,cv=10).mean())
# Out:
# C:\Users\Hammad\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 5 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# KfoldCrossVal score using SVM is 0.8857142857142858

# %%
Kfold = KFold(len(x),shuffle = False)
print("KfoldCrossVal score using Random Forest is %s" %cross_val_score(classifier_3,x,y,cv=10).mean())
# Out:
# C:\Users\Hammad\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 5 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# KfoldCrossVal score using Random Forest is 0.8095238095238095

# %%
Kfold = KFold(len(x),shuffle = False)
print("KfoldCrossVal score using KNN is %s" %cross_val_score(knn,x,y,cv=10).mean())
# Out:
# C:\Users\Hammad\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 5 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# KfoldCrossVal score using KNN is 0.838095238095238

# %%
Kfold = KFold(len(x),shuffle = False)
print("KfoldCrossVal score using Naive Bay's is %s" %cross_val_score(gnb,x,y,cv=10).mean())
# Out:
# C:\Users\Hammad\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 5 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# KfoldCrossVal score using Naive Bay's is 0.7952380952380953

# %%
#Specificity&Sensitivity

# %%
from sklearn import metrics

# %%
#predicting the test set result for Model1
ypred_1 = classifier_1.predict(xtest)
print (ypred_1)
# Out:
# ['Brain' 'Bone' 'Lung' 'Lung' 'Lung' 'Liver' 'Bone' 'Liver' 'Brain'
#  'Brain' 'Lung' 'Lung' 'Brain' 'Bone' 'Lung' 'Brain' 'Brain' 'Liver'
#  'Brain' 'Brain']

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
cm1 = confusion_matrix(ytest, ypred_1)
pd.crosstab(ytest, ypred_1, rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted  Bone  Brain  Liver  Lung
# Actual
# Bone          3      0      1     0
# Brain         0      7      0     0
# Liver         0      1      0     0
# Lung          0      0      2     6

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(ytest, ypred_1))
# Out:
# Accuracy: 0.8

# %%
#Model Evaluation
print("Model evaluation\n" + classification_report(ytest,ypred_1))
# Out:
# Model evaluation
#               precision    recall  f1-score   support
#
#         Bone       1.00      0.75      0.86         4
#        Brain       0.88      1.00      0.93         7
#        Liver       0.00      0.00      0.00         1
#         Lung       1.00      0.75      0.86         8
#
#     accuracy                           0.80        20
#    macro avg       0.72      0.62      0.66        20
# weighted avg       0.91      0.80      0.84        20

# %%
#Model2
ypred_2 = classifier_2.predict(xtest)
print (ypred_2)
# Out:
# ['Brain' 'Bone' 'Lung' 'Lung' 'Lung' 'Brain' 'Bone' 'Bone' 'Brain' 'Brain'
#  'Lung' 'Lung' 'Brain' 'Bone' 'Lung' 'Brain' 'Brain' 'Bone' 'Brain'
#  'Brain']

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cm2 = confusion_matrix(ytest, ypred_2)
cm2_df = pd.DataFrame(cm2,index = ['Brain','Bone', 'Lung', 'Liver'], columns = ['Brain','Bone', 'Lung', 'Liver'])
plt.figure(figsize=(8,6))
sns.heatmap(cm2_df, annot=True)
plt.title('SVM \nAccuracy:{0:.3f}')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
def plot_classification_report(cr, title='Classification report ', with_avg_total=False, cmap=plt.cm.Blues):

    lines = cr.split('\n')

    classes = []
    plotMat = []
    for line in lines[2 : (len(lines) - 3)]:
        #print(line)
        t = line.split()
        # print(t)
        classes.append(t[0])
        v = [float(x) for x in t[1: len(t) - 1]]
        print(v)
        plotMat.append(v)

    if with_avg_total:
        aveTotal = lines[len(lines) - 1].split()
        classes.append('avg/total')
        vAveTotal = [float(x) for x in t[1:len(aveTotal) - 1]]
        plotMat.append(vAveTotal)


    plt.imshow(plotMat, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    x_tick_marks = np.arange(3)
    y_tick_marks = np.arange(len(classes))
    plt.xticks(x_tick_marks, ['precision', 'recall', 'f1-score'], rotation=45)
    plt.yticks(y_tick_marks, classes)
    plt.tight_layout()
    plt.ylabel('Classes')
    plt.xlabel('Measures')

# %%
sampleClassificationReport = """precision    recall  f1-score   support

                   0.71      1.00      0.83         5
                   0.75      1.00      0.86         3
                   1.00      0.50      0.67         4
                   0.00      0.00      0.00         1
weighted avg       0.76      0.77      0.72        13
    
"""
plot_classification_report(sampleClassificationReport)
# Out:
# [1.0, 0.83]
# [1.0, 0.86]
# [0.5, 0.67]
# [0.0, 0.0]

# %%
cm2 = confusion_matrix(ytest, ypred_2)
pd.crosstab(ytest, ypred_2, rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted  Bone  Brain  Lung
# Actual
# Bone          4      0     0
# Brain         0      7     0
# Liver         0      1     0
# Lung          1      1     6

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(ytest, ypred_2))
# Out:
# Accuracy: 0.85

# %%
#Model Evaluation
print("Model evaluation\n" + classification_report(ytest,ypred_2))
# Out:
# C:\Users\Hammad\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model evaluation
#               precision    recall  f1-score   support
#
#         Bone       0.80      1.00      0.89         4
#        Brain       0.78      1.00      0.88         7
#        Liver       0.00      0.00      0.00         1
#         Lung       1.00      0.75      0.86         8
#
#     accuracy                           0.85        20
#    macro avg       0.64      0.69      0.66        20
# weighted avg       0.83      0.85      0.83        20

# %%
#Model3
ypred_3= classifier_3.predict(xtest)
print (ypred_3)
# Out:
# ['Brain' 'Bone' 'Lung' 'Lung' 'Lung' 'Liver' 'Bone' 'Brain' 'Brain'
#  'Brain' 'Lung' 'Lung' 'Brain' 'Bone' 'Lung' 'Brain' 'Brain' 'Bone'
#  'Brain' 'Brain']

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
cm3 = confusion_matrix(ytest, ypred_3)
pd.crosstab(ytest, ypred_3, rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted  Bone  Brain  Liver  Lung
# Actual
# Bone          3      1      0     0
# Brain         0      7      0     0
# Liver         0      1      0     0
# Lung          1      0      1     6

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(ytest, ypred_3))
# Out:
# Accuracy: 0.8

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
#Model Evaluation
print("Model evaluation\n" + classification_report(ytest,ypred_3))
# Out:
# Model evaluation
#               precision    recall  f1-score   support
#
#         Bone       0.75      0.75      0.75         4
#        Brain       0.78      1.00      0.88         7
#        Liver       0.00      0.00      0.00         1
#         Lung       1.00      0.75      0.86         8
#
#     accuracy                           0.80        20
#    macro avg       0.63      0.62      0.62        20
# weighted avg       0.82      0.80      0.80        20

# %%
#Model 4
ypred_4 = knn.predict(xtest)
ypred_4
# Out:
# array(['Brain', 'Bone', 'Lung', 'Lung', 'Lung', 'Brain', 'Bone', 'Brain',
#        'Brain', 'Brain', 'Brain', 'Lung', 'Brain', 'Bone', 'Lung',
#        'Brain', 'Brain', 'Brain', 'Brain', 'Brain'], dtype=object)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
cm4 = confusion_matrix(ytest, ypred_4)
pd.crosstab(ytest, ypred_4, rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted  Bone  Brain  Lung
# Actual
# Bone          3      1     0
# Brain         0      7     0
# Liver         0      1     0
# Lung          0      3     5

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(ytest, ypred_4))
# Out:
# Accuracy: 0.75

# %%
#Model Evaluation
print("Model evaluation\n" + classification_report(ytest,ypred_4))
# Out:
# C:\Users\Hammad\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model evaluation
#               precision    recall  f1-score   support
#
#         Bone       1.00      0.75      0.86         4
#        Brain       0.58      1.00      0.74         7
#        Liver       0.00      0.00      0.00         1
#         Lung       1.00      0.62      0.77         8
#
#     accuracy                           0.75        20
#    macro avg       0.65      0.59      0.59        20
# weighted avg       0.80      0.75      0.74        20

# %%
#Model 5
ypred_5 = gnb.predict(xtest)
ypred_5
# Out:
# array(['Brain', 'Bone', 'Lung', 'Lung', 'Lung', 'Lung', 'Bone', 'Bone',
#        'Brain', 'Brain', 'Lung', 'Lung', 'Brain', 'Bone', 'Lung', 'Brain',
#        'Brain', 'Liver', 'Brain', 'Brain'], dtype='<U5')

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
cm5 = confusion_matrix(ytest, ypred_5)
pd.crosstab(ytest, ypred_5, rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted  Bone  Brain  Liver  Lung
# Actual
# Bone          4      0      0     0
# Brain         0      7      0     0
# Liver         0      1      0     0
# Lung          0      0      1     7

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(ytest, ypred_5))
# Out:
# Accuracy: 0.9

# %%
#Model Evaluation
print("Model evaluation\n" + classification_report(ytest,ypred_5))
# Out:
# Model evaluation
#               precision    recall  f1-score   support
#
#         Bone       1.00      1.00      1.00         4
#        Brain       0.88      1.00      0.93         7
#        Liver       0.00      0.00      0.00         1
#         Lung       1.00      0.88      0.93         8
#
#     accuracy                           0.90        20
#    macro avg       0.72      0.72      0.72        20
# weighted avg       0.91      0.90      0.90        20
